# %% [markdown]
# # Data Analysis Assignment
# ## Topics: Control Flow · Loops & Iteration · Logical Operators · Core Operations
#
# **Dataset:** `student_performance.csv`
#
# **Columns**
# - `student_id`, `gender`, `age`
# - `study_hours` hours studied per day
# - `attendance` attendance percentage
# - `math_score`, `science_score`, `english_score`, `history_score` (0-100)
# - `internet_access` (Yes/No), `extra_activities` (Yes/No)
#
# **Instructions**
# - Read each task carefully and write your code in the empty cell below it.
# - Aim to use loops, conditionals, and logical operators where indicated.
# - A passing score is **>= 60** in any subject.
# - Run all cells from top to bottom before submitting.

# %% [markdown]
# ## Setu run this first

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

df = pd.read_csv('student_performance.csv')
df.head()

# %% [markdown]
# ---
# # Section 1 Core Operations

# %% [markdown]
# ### Task 1.1 Inspect the data
# Print the **shape** of the dataset, the **column names**, and basic summary statistics
# (use `.describe()`) for the numeric columns.

# %%
# Your code here

# %% [markdown]
# ### Task 1.2 Create a total & average score column
# Create a new column `total_score` = sum of the four subject scores, and a column
# `average_score` = the mean of the four subjects (rounded to 1 decimal).
# Display the first 5 rows showing `student_id` and the two new columns.

# %%
# Your code here

# %% [markdown]
# ---
# # Section 2  Logical Operators

# %% [markdown]
# ### Task 2.1  High achievers
# Using logical operators, find all students who studied **more than 6 hours** per day
# **AND** have an `average_score` of **80 or above**. Print how many such students exist
# and display them.

# %%
# Your code here

# %% [markdown]
# ### Task 2.2 At-risk students
# Find students who are **at risk**: either `attendance` below 60
# **OR** `average_score` below 50. Then, using the **NOT** operator (`~`),
# count how many students are NOT at risk.

# %%
# Your code here

# %% [markdown]
# ---
# # Section 3 Control Flow

# %% [markdown]
# ### Task 3.1 Assign letter grades
# Write a function `assign_grade(score)` that uses **if/elif/else** to return:
# - `'A'` if score >= 85
# - `'B'` if score >= 70
# - `'C'` if score >= 50
# - `'F'` otherwise
#
# Apply it to `average_score` to create a new column `grade`. Show the count of each grade.

# %%
# Your code here

# %% [markdown]
# ---
# # Section 4 Loops & Iteration

# %% [markdown]
# ### Task 4.1 Average per subject using a loop
# Using a **for loop**, iterate over the four subject columns and print the
# class average for each subject (rounded to 1 decimal).

# %%
# Your code here

# %% [markdown]
# ### Task 4.2 Count passing students per subject
# Loop through each subject. For each one, use a counter and a conditional inside the loop
# (or a vectorized comparison) to count how many students **passed** (score >= 50).
# Store results in a dictionary `pass_counts` and print it.

# %%
# Your code here

# %% [markdown]
# ### Task 4.3 Performance category
# Using a loop (or list comprehension) over `average_score`, build a list that labels each
# student as `'Excellent'` (>=80), `'Good'` (>=60), or `'Needs Improvement'` (<60).
# Add it as a column `performance` and show the value counts.

# %%
# Your code here

# %% [markdown]
# ---
# # Section 5 Visualization

# %% [markdown]
# ### Task 5.1 Bar chart
# Using the `pass_counts` dictionary from Task 4.2, create a **bar chart** showing the
# number of passing students per subject. Add a title and axis labels.

# %%
# Your code here

# %% [markdown]
# ### Task 5.2 Two plots
# 1. A bar chart (or countplot) of the `grade` distribution.
# 2. A scatter plot of `study_hours` (x) vs `average_score` (y), colored by `grade`.
# What relationship do you observe? Write a 1-2 sentence comment.

# %%
# Your code here

# %% [markdown]
# ### Bonus Challenge
# Using a loop, go through each student and build a summary string for the **top 5**
# students by `total_score`, for example:
# `"Student 1023 (Female) - Avg: 88.5, Grade: A"`.
# Print each line.

# %%
# Your code here
